# %% [markdown]
# # Forecasting of Electricity Consumption in India

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
df=pd.read_csv('electricity_consumption.csv')

# %%
df.rename(columns={"Unnamed: 0": "Date"}, errors="raise",inplace  = True)

# %%
df['India_Consumption']=df.sum(axis = 1, skipna = True)

# %%
df = df[['Date','India_Consumption']]

# %%
df
# Out:
#                     Date  India_Consumption
# 0    02/01/2019 00:00:00             3373.4
# 1    03/01/2019 00:00:00             3403.7
# 2    04/01/2019 00:00:00             3304.1
# 3    05/01/2019 00:00:00             3308.9
# 4    06/01/2019 00:00:00             3316.9
# ..                   ...                ...
# 498  01/12/2020 00:00:00             3741.5
# 499  02/12/2020 00:00:00             3763.8
# 500  03/12/2020 00:00:00             3726.6
# 501  04/12/2020 00:00:00             3642.1
# 502  05/12/2020 00:00:00             3407.0
#
# [503 rows x 2 columns]

# %%
df['India_Consumption'].value_counts()
# Out:
# 3654.3    2
# 3483.4    2
# 3642.2    2
# 3853.8    2
# 3682.3    2
#          ..
# 3532.7    1
# 3638.4    1
# 3333.1    1
# 3558.0    1
# 3948.0    1
# Name: India_Consumption, Length: 492, dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
mean = df['India_Consumption'].mean()

# %%
std = df['India_Consumption'].std()

# %%
h = df['India_Consumption']

# %%
h = sorted(h)

# %%
normalised = norm.pdf(h,mean,std)

# %%
plt.scatter(h,normalised,c='r')

# %% [markdown]
# ## Follows a Normal Distribution

# %%
normalised
# Out:
# array([4.34071448e-05, 4.75892413e-05, 5.76325071e-05, 6.37817972e-05,
#        6.83778304e-05, 7.73839655e-05, 7.76629001e-05, 9.64286255e-05,
#        1.01527623e-04, 1.12295388e-04, 1.12370592e-04, 1.12822658e-04,
#        1.20094186e-04, 1.22490744e-04, 1.26815947e-04, 1.30919751e-04,
#        1.41314888e-04, 1.46976410e-04, 1.57542799e-04, 1.74824299e-04,
#        1.77053272e-04, 1.78229203e-04, 1.82335993e-04, 1.89633909e-04,
#        2.08928697e-04, 2.10981456e-04, 2.26391477e-04, 2.61227628e-04,
#        2.64900891e-04, 2.67464190e-04, 2.87517388e-04, 3.14527459e-04,
#        3.23337503e-04, 3.30004181e-04, 3.33616204e-04, 3.44597259e-04,
#        3.47460768e-04, 3.51527686e-04, 3.56308274e-04, 3.63551155e-04,
#        3.86510152e-04, 3.87049501e-04, 4.11568982e-04, 4.11941212e-04,
#        4.27547696e-04, 4.31926633e-04, 4.34603434e-04, 4.41718836e-04,
#        4.55928914e-04, 4.57303293e-04, 4.76354175e-04, 4.79163326e-04,
# ...

# %%
h
# Out:
# [2555.7999999999997,
#  2567.4999999999995,
#  2592.3999999999996,
#  2605.9,
#  2615.2999999999997,
#  2632.3,
#  2632.7999999999997,
#  2663.5000000000005,
#  2671.0000000000005,
#  2685.9000000000005,
#  2686.0,
#  2686.6,
#  2696.0,
#  2699.0,
#  2704.3,
#  2709.2000000000003,
#  2721.1,
#  2727.2999999999997,
#  2738.3999999999996,
#  2755.4,
#  2757.5,
#  2758.6,
#  2762.4,
#  2769.0000000000005,
#  2785.6,
#  2787.2999999999997,
#  2799.7000000000003,
#  2825.7000000000003,
#  2828.3,
#  2830.1,
#  2843.7999999999997,
#  2861.3,
#  2866.8,
#  2870.8999999999996,
#  2873.1,
#  2879.7,
#  2881.4,
#  2883.8,
#  2886.6,
#  2890.7999999999997,
#  2903.8,
#  2904.1,
#  2917.5000000000005,
#  2917.7000000000003,
#  2925.9999999999995,
#  2928.2999999999997,
#  2929.7,
#  2933.3999999999996,
#  2940.7,
#  2941.4000000000005,
#  2950.9999999999995,
#  2952.4,
#  2954.9,
#  2956.2,
#  2959.9,
#  2989.0,
#  2994.2000000000003,
#  2999.2,
#  3000.0,
#  3000.9,
#  3003.3,
#  3004.0,
# ...

# %%
df
# Out:
#                     Date  India_Consumption
# 0    02/01/2019 00:00:00             3373.4
# 1    03/01/2019 00:00:00             3403.7
# 2    04/01/2019 00:00:00             3304.1
# 3    05/01/2019 00:00:00             3308.9
# 4    06/01/2019 00:00:00             3316.9
# ..                   ...                ...
# 498  01/12/2020 00:00:00             3741.5
# 499  02/12/2020 00:00:00             3763.8
# 500  03/12/2020 00:00:00             3726.6
# 501  04/12/2020 00:00:00             3642.1
# 502  05/12/2020 00:00:00             3407.0
#
# [503 rows x 2 columns]

# %%
ax= df.plot(figsize=(20,10))
ax.set_xlabel("h")
ax.set_ylabel("Normalized")
# Out:
# Text(0, 0.5, 'Normalized')

# %% [markdown]
# ### Testing for Stationarity with Dicky Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_results = adfuller(df['India_Consumption'])

# %%
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['India_Consumption'])
# Out:
# ADF Test Statistic : -5.94008937986656
# p-value : 2.2717840848590585e-07
# #Lags Used : 7
# Number of Observations Used : 495
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df['1st Differencing'] = df['India_Consumption']-df['India_Consumption'].shift(30)
# Out:
# C:\Users\KIIT\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Hence the Data is Stationary...So no need of Differencing

# %% [markdown]
# ### Final Thoughts on Autocorrelation and Partial Autocorrelation
# Identification of an AR model is often best done with the PACF.
# For an AR model, the theoretical PACF “shuts off” past the order of the model. The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point. Put another way, the number of non-zero partial autocorrelations gives the order of the AR model. By the “order of the model” we mean the most extreme lag of x that is used as a predictor.
# Identification of an MA model is often best done with the ACF rather than the PACF.
#
# For an MA model, the theoretical PACF does not shut off, but instead tapers toward 0 in some manner. A clearer pattern for an MA model is in the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
#
# p,d,q p AR model lags d differencing q MA lags

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(df['1st Differencing'].dropna(),lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(df['1st Differencing'].dropna(),lags=40,ax=ax2)

# %%
# p=2,d=0,q=6
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# ## Here it is a seasonal data.... so we will use SARIMAX

# %%
import statsmodels.api as sm
       
model=sm.tsa.statespace.SARIMAX(df['India_Consumption'],order=(5,1,5),seasonal_order=(5,1,5,30))
results=model.fit()
# Out:
# C:\Users\KIIT\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:1008: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\KIIT\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
df['forecast']=results.predict(start=400,end=503,dynamic=True)
df[['India_Consumption','forecast']].plot(figsize=(12,8))
# Out:
# C:\Users\KIIT\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:>
